# %%
import os
os.environ['OPENAI_API_KEY'] = "voc-1420558188126677432688569036a6e03bf58.72907303"
os.environ["OPENAI_API_BASE"] = "https://openai.vocareum.com/v1"

# %%
# %pip install --upgrade --quiet  langchain-openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.2/471.2 kB 15.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.27 requires langchain-core<1.0.0,>=0.3.72, but you have langchain-core 1.0.4 which is incompatible.

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)

# %%
INSTRUCTION = "Generate a CSV file with at least 10 real estate listing."
SAMPLE_LISTING = \
"""
Neighborhood: Green Oaks
Price: $800,000
Bedrooms: 3
Bathrooms: 2
House Size: 2,000 sqft

Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.

Neighborhood Description: Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze.
"""

# %%
from pydantic import BaseModel, Field, NonNegativeInt
from typing import List
class RealEstateListing(BaseModel):
    Neighborhood: str = Field(description="The neighborhood where the property is located")
    price: NonNegativeInt = Field(description="THe price of the property in USD")
    bedrooms: NonNegativeInt = Field(description="The number of bedrooms in the property")
    bathrooms: NonNegativeInt = Field(description="The number of bathrooms in the property")
    house_size: NonNegativeInt = Field(description="The size of the house in square feet")
    description: str = Field(description="A description of the property")
    neighborhood_description: str = Field(description="A description of the neighborhood")

class ListingCollection(BaseModel):
    listings: List[RealEstateListing] = Field(description="A list of real estate listings")

# %%
from langchain_core.output_parsers import PydanticOutputParser
parser = PydanticOutputParser(pydantic_object=ListingCollection)

# %%
from langchain_core.prompts import PromptTemplate



prompt = PromptTemplate(
    template="{instruction}\n{sample}\n{format_instructions}\n",
    input_variables=["instruction", "sample"],
    partial_variables={"format_instructions": parser.get_format_instructions},
)

print(prompt)
# Out:
# input_variables=['instruction', 'sample'] input_types={} partial_variables={'format_instructions': <bound method PydanticOutputParser.get_format_instructions of PydanticOutputParser(pydantic_object=<class '__main__.ListingCollection'>)>} template='{instruction}\n{sample}\n{format_instructions}\n'

# %%
query = prompt.format(instruction=INSTRUCTION, sample=SAMPLE_LISTING)
print(query)
# Out:
# Generate a CSV file with at least 10 real estate listing.
#
# Neighborhood: Green Oaks
# Price: $800,000
# Bedrooms: 3
# Bathrooms: 2
# House Size: 2,000 sqft
#
# Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.
#
# Neighborhood Description: Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze.
#
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"$defs": {"RealEstateListing": {"properties": {"Neighborhood": {"description": "The neighborhood where the property is located", "title": "Neighborhood", "type": "string"}, "price": {"description": "THe price of the property in USD", "minimum": 0, "title": "Price", "type": "integer"}, "bedrooms": {"description": "The number of bedrooms in the property", "minimum": 0, "title": "Bedrooms", "type": "integer"}, "bathrooms": {"description": "The number of bathrooms in the property", "minimum": 0, "title": "Bathrooms", "type": "integer"}, "house_size": {"description": "The size of the house in square feet", "minimum": 0, "title": "House Size", "type": "integer"}, "description": {"description": "A description of the property", "title": "Description", "type": "string"}, "neighborhood_description": {"description": "A description of the neighborhood", "title": "Neighborhood Description", "type": "string"}}, "required": ["Neighborhood", "price", "bedrooms", "bathrooms", "house_size", "description", "neighborhood_description"], "title": "RealEstateListing", "type": "object"}}, "properties": {"listings": {"description": "A list of real estate listings", "items": {"$ref": "#/$defs/RealEstateListing"}, "title": "Listings", "type": "array"}}, "required": ["listings"]}
# ```

# %%
response = llm.invoke(query)

# %%
print(response.content)
# Out:
# {
#   "listings": [
#     {
#       "Neighborhood": "Green Oaks",
#       "price": 800000,
#       "bedrooms": 3,
#       "bathrooms": 2,
#       "house_size": 2000,
#       "description": "Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.",
#       "neighborhood_description": "Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze."
#     },
#     {
#       "Neighborhood": "Sunnyvale",
#       "price": 950000,
#       "bedrooms": 4,
#       "bathrooms": 3,
#       "house_size": 2500,
#       "description": "Located in the desirable neighborhood of Sunnyvale, this 4-bedroom, 3-bathroom home offers spacious living areas and a beautifully landscaped backyard. The updated kitchen features stainless steel appliances and granite countertops, perfect for entertaining guests. Relax in the luxurious master suite with a spa-like bathroom and walk-in closet. Enjoy the California sunshine in the private backyard oasis with a pool and patio area.",
#       "neighborhood_description": "Sunnyvale is known for its top-rated schools, family-friendly parks, and vibrant downtown area. Explore the nearby farmers' market or take a hike in the scenic hills. With easy access to major tech companies and freeways, this home is perfect for Silicon Valley professionals."
#     },
#     {
#       "Neighborhood": "Brooklyn Heights",
#       "price": 1200000,
#       "bedrooms": 5,
#       "bathrooms": 4,
#       "house_size": 3500,
#       "description": "Welcome to this stunning 5-bedroom, 4-bathroom home in the historic neighborhood of Brooklyn Heights. The grand foyer leads to a formal living room with a fireplace and a spacious dining area, perfect for hosting dinner parties. The gourmet kitchen features high-end appliances and a breakfast nook overlooking the landscaped backyard. Retreat to the luxurious master suite with a private balcony and spa-like bathroom. This elegant home combines classic charm with modern amenities.",
#       "neighborhood_description": "Brooklyn Heights is known for its tree-lined streets, historic brownstones, and waterfront views. Explore the nearby Brooklyn Bridge Park or dine at the trendy restaurants along Montague Street. With easy access to Manhattan via subway or ferry, this home offers the best of city living."
#     },
#     {
#       "Neighborhood": "Pacific Palisades",
#       "price": 3500000,
#       "bedrooms": 6,
#       "bathrooms": 5,
#       "house_size": 5000,
#       "description": "Located in the prestigious neighborhood of Pacific Palisades, this 6-bedroom, 5-bathroom home offers luxury living at its finest. The grand entryway leads to a formal living room with high ceilings and a cozy fireplace. The chef's kitchen features top-of-the-line appliances and a large island, perfect for gourmet cooking. Relax in the resort-style backyard with a pool, spa, and outdoor kitchen. The spacious master suite includes a sitting area, dual walk-in closets, and a spa-like bathroom.",
#       "neighborhood_description": "Pacific Palisades is known for its upscale homes, scenic views, and exclusive country clubs. Enjoy hiking in the nearby Santa Monica Mountains or shopping at the upscale boutiques on Sunset Boulevard. With easy access to the beach and top-rated schools, this home offers the ultimate California lifestyle."
#     },
#     {
#       "Neighborhood": "Back Bay",
#       "price": 2500000,
#       "bedrooms": 4,
#       "bathrooms": 3,
#       "house_size": 3000,
#       "description": "Welcome to this elegant 4-bedroom, 3-bathroom home in the prestigious neighborhood of Back Bay. The formal living room features a fireplace and French doors that open to a private courtyard. The gourmet kitchen boasts custom cabinetry, high-end appliances, and a breakfast nook. Retreat to the luxurious master suite with a spa-like bathroom and walk-in closet. The landscaped backyard offers a tranquil retreat with a fountain and outdoor dining area.",
#       "neighborhood_description": "Back Bay is known for its upscale homes, tree-lined streets, and proximity to the Newport Back Bay Nature Preserve. Explore the nearby Fashion Island shopping center or dine at the trendy restaurants along Pacific Coast Highway. With easy access to the beach and top-rated schools, this home is perfect for coastal living."
#     },
#     {
#       "Neighborhood": "Tribeca",
#       "price": 5000000,
#       "bedrooms": 3,
#       "bathrooms": 4,
#       "house_size": 4000,
#       "description": "Located in the trendy neighborhood of Tribeca, this 3-bedroom, 4-bathroom loft offers luxury living in the heart of Manhattan. The open-concept living space features high ceilings, exposed brick walls, and oversized windows with city views. The chef's kitchen boasts top-of-the-line appliances and a large island, perfect for entertaining. Retreat to the spacious master suite with a spa-like bathroom and walk-in closet. This modern loft combines industrial chic with upscale amenities.",
#       "neighborhood_description": "Tribeca is known for its cobblestone streets, art galleries, and celebrity residents. Explore the nearby Hudson River Park or dine at the Michelin-starred restaurants along Greenwich Street. With easy access to public transportation and cultural attractions, this loft offers the best of downtown living."
#     },
#     {
#       "Neighborhood": "Beverly Hills",
#       "price": 10000000,
#       "bedrooms": 7,
#       "bathrooms": 6,
#       "house_size": 6000,
#       "description": "Welcome to this luxurious 7-bedroom, 6-bathroom estate in the prestigious neighborhood of Beverly Hills. The grand foyer leads to a formal living room with a fireplace and a formal dining room with a crystal chandelier. The gourmet kitchen features custom cabinetry, high-end appliances, and a breakfast nook. Relax in the opulent master suite with a sitting area, dual walk-in closets, and a spa-like bathroom. The landscaped backyard offers a pool, spa, and outdoor kitchen, perfect for entertaining guests.",
#       "neighborhood_description": "Beverly Hills is known for its upscale homes, celebrity residents, and luxury shopping on Rodeo Drive. Explore the nearby Beverly Hills Hotel or dine at the trendy restaurants along Canon Drive. With easy access to the beach and top-rated schools, this estate offers the ultimate California lifestyle."
#     },
#     {
#       "Neighborhood": "Georgetown",
#       "price": 1500000,
#       "bedrooms": 5,
#       "bathrooms": 4,
#       "house_size": 3500,
#       "description": "Located in the historic neighborhood of Georgetown, this 5-bedroom, 4-bathroom townhouse offers classic charm with modern amenities. The formal living room features a fireplace and custom millwork, perfect for cozy evenings. The gourmet kitchen boasts high-end appliances, marble countertops, and a breakfast nook. Retreat to the luxurious master suite with a spa-like bathroom and walk-in closet. The private rooftop terrace offers panoramic views of the city skyline.",
#       "neighborhood_description": "Georgetown is known for its cobblestone streets, historic architecture, and upscale boutiques. Explore the nearby C&O Canal or dine at the trendy restaurants along M Street. With easy access to downtown DC and cultural attractions, this townhouse offers the best of city living."
#     },
#     {
#       "Neighborhood": "Malibu",
#       "price": 7500000,
#       "bedrooms": 6,
#       "bathrooms": 5,
#       "house_size": 5000,
#       "description": "Welcome to this beachfront 6-bedroom, 5-bathroom estate in the exclusive neighborhood of Malibu. The grand entryway leads to a formal living room with floor-to-ceiling windows and a fireplace. The chef's kitchen features top-of-the-line appliances, a large island, and a breakfast nook. Relax in the luxurious master suite with a private balcony, dual walk-in closets, and a spa-like bathroom. The landscaped backyard offers direct access to the sandy beach and stunning ocean views.",
#       "neighborhood_description": "Malibu is known for its upscale homes, celebrity residents, and pristine beaches. Enjoy surfing at Zuma Beach or hiking in the nearby Santa Monica Mountains. With easy access to the beach and top-rated schools, this estate offers the ultimate California lifestyle."
#     },
#     {
#       "Neighborhood": "South Beach",
#       "price": 3000000,
#       "bedrooms": 4,
#       "bathrooms": 3,
#       "house_size": 3000,
#       "description": "Located in the vibrant neighborhood of South Beach, this 4-bedroom, 3-bathroom condo offers luxury living with panoramic views of the bay. The open-concept living space features floor-to-ceiling windows, a gourmet kitchen, and a spacious dining area. The master suite includes a spa-like bathroom and walk-in closet. Relax on the private balcony with stunning views of the city skyline and waterfront.",
#       "neighborhood_description": "South Beach is known for its trendy restaurants, art galleries, and nightlife. Explore the nearby Embarcadero waterfront or shop at the upscale boutiques along Union Street. With easy access to public transportation and cultural attractions, this condo offers the best of urban living."
#     }
#   ]
# }

# %%
import pandas as pd

result = parser.parse(response.content)
df = pd.DataFrame([listing.model_dump() for listing in result.listings])
df.head()


# METHOD 2
# import json
# data = json.loads(result.json())
# df = pd.DataFrame(data["listings"])
# df.head()
# Out:
#         Neighborhood    price  bedrooms  bathrooms  house_size  \
# 0         Green Oaks   800000         3          2        2000
# 1          Sunnyvale   950000         4          3        2500
# 2   Brooklyn Heights  1200000         5          4        3500
# 3  Pacific Palisades  3500000         6          5        5000
# 4           Back Bay  2500000         4          3        3000
#
#                                          description  \
# 0  Welcome to this eco-friendly oasis nestled in ...
# 1  Located in the desirable neighborhood of Sunny...
# 2  Welcome to this stunning 5-bedroom, 4-bathroom...
# 3  Located in the prestigious neighborhood of Pac...
# 4  Welcome to this elegant 4-bedroom, 3-bathroom ...
#
#                             neighborhood_description
# 0  Green Oaks is a close-knit, environmentally-co...
# 1  Sunnyvale is known for its top-rated schools, ...
# 2  Brooklyn Heights is known for its tree-lined s...
# 3  Pacific Palisades is known for its upscale hom...
# 4  Back Bay is known for its upscale homes, tree-...

# %%
df.to_csv('real_sestate_listings.csv', index_label='id')

# %%
import os
os.environ['OPENAI_API_KEY'] = "voc-1420558188126677432688569036a6e03bf58.72907303"
os.environ["OPENAI_API_BASE"] = "https://openai.vocareum.com/v1"

# %%
# %pip install --upgrade --quiet  langchain-community
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 49.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 42.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# langchain 0.3.27 requires langchain-core<1.0.0,>=0.3.72, but you have langchain-core 1.0.4 which is incompatible.
# langchain 0.3.27 requires langchain-text-splitters<1.0.0,>=0.3.9, but you have langchain-text-splitters 1.0.0 which is incompatible.

# %%
# %pip install --upgrade --quiet chromadb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.8/20.8 MB 91.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 21.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 64.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 96.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.9/65.9 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.0/208.0 kB 15.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 517.7/517.7 kB 31.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.4/128.4 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 107.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 456.8/456.8 kB 30.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.7 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.37.0 requires opentelemetry-exporter-otlp-proto-common==1.37.0, but you have opentelemetry-exporter-otlp-proto-common 1.38.0 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.37.0 requires opentelemetry-proto==1.37.0, but you have opentelemetry-proto 1.38.0 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.37.0 requires opentelemetry-sdk~=1.37.0, but you have opentelemetry-sdk 1.38.0 which is incompatible.
# google-adk 1.17.0 requires opentelemetry-api<=1.37.0,>=1.37.0, but you have opentelemetry-api 1.38.0 which is incompatible.
# google-adk 1.17.0 requires opentelemetry-sdk<=1.37.0,>=1.37.0, but you have opentelemetry-sdk 1.38.0 which is incompatible.
# langchain 0.3.27 requires langchain-core<1.0.0,>=0.3.72, but you have langchain-core 1.0.4 which is incompatible.
# langchain 0.3.27 requires langchain-text-splitters<1.0.0,>=0.3.9, but you have langchain-text-splitters 1.0.0 which is incompatible.

# %%
import shutil
from langchain_openai import OpenAIEmbeddings
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma
import pandas as pd
import os

CHROMA_PATH = "/content/chroma"
CSV_PATH = "real_sestate_listings.csv"

embedding_function = OpenAIEmbeddings()

df = pd.read_csv(CSV_PATH)
documents = []
for index, row in df.iterrows():
    documents.append(Document(page_content=row['description'], metadata={'id': str(index)}))

text_splitter=RecursiveCharacterTextSplitter(
    chunk_size=300,
    chunk_overlap=100,
    length_function=len,
    add_start_index=True,
)

chunks = text_splitter.split_documents(documents)
print(f"Split {len(documents)} documents into {len(chunks)} chunks.")

if chunks:
    document = chunks[10]
    print(document.page_content)
    print(document.metadata)

if os.path.exists(CHROMA_PATH):
    shutil.rmtree(CHROMA_PATH)

db = Chroma.from_documents(chunks, OpenAIEmbeddings(), persist_directory=CHROMA_PATH)


db.persist()
print(f"Saved {len(chunks)} chunks to {CHROMA_PATH}")
# Out:
# Split 10 documents into 22 chunks.
# gourmet kitchen boasts custom cabinetry, high-end appliances, and a breakfast nook. Retreat to the luxurious master suite with a spa-like bathroom and walk-in closet. The landscaped backyard offers a tranquil retreat with a fountain and outdoor dining area.
# {'id': '4', 'start_index': 195}
# Saved 22 chunks to /content/chroma
# /tmp/ipython-input-308074583.py:40: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   db.persist()

# %%
# ✅ Create and persist the Chroma vector database

from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma

# Initialize embedding model
embeddings = OpenAIEmbeddings()

# Define directory for persistence (you already use CHROMA_PATH)
persist_directory = CHROMA_PATH

# Assuming your documents are stored in a variable called `docs`
db = Chroma.from_documents(chunks, embeddings, persist_directory=persist_directory)

# Persist the database
db.persist()
print("✅ Vector database created and saved at:", persist_directory)
# Out:
# ✅ Vector database created and saved at: /content/chroma

# %%
query_text = "A comfortable three-bedroom house with a spacious kitchen and a cozy living room."

BASIC_PROMPT_TEMPLATE = \
"""
Based on the following context:

{context}


-----

Answer the question : {question}
"""

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI


def predict_response(query_text, PROMPT_TEMPLATE):
    embedding_function = OpenAIEmbeddings()
    db = Chroma(persist_directory=CHROMA_PATH, embedding_function=embedding_function)

    # Search the DB.
    results = db.similarity_search_with_relevance_scores(query_text, k=3)
    if len(results) == 0 or results[0][1] < 0.7:
        print(f"Unable to find matching results.")
    else:
        context_text = "\n\n---\n\n".join([doc.page_content for doc, _score in results])
        prompt_template = ChatPromptTemplate.from_template(PROMPT_TEMPLATE)
        prompt = prompt_template.format(context=context_text, question=query_text)
        print(f"Generated Prompt:\n{prompt}")

        model = ChatOpenAI()
        response_text = model.invoke(prompt).content
        sources = [doc.metadata.get("id", None) for doc, _score in results]
        formatted_response = f"Response: {response_text}\nSources: {sources}"
        print(formatted_response)

# %%
predict_response(query_text, BASIC_PROMPT_TEMPLATE)
# Out:
# /tmp/ipython-input-2526889268.py:7: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the `langchain-chroma package and should be used instead. To use it run `pip install -U `langchain-chroma` and import as `from `langchain_chroma import Chroma``.
#   db = Chroma(persist_directory=CHROMA_PATH, embedding_function=embedding_function)
# Generated Prompt:
# Human:
# Based on the following context:
#
# for hosting dinner parties. The gourmet kitchen features high-end appliances and a breakfast nook overlooking the landscaped backyard. Retreat to the luxurious master suite with a private balcony and spa-like bathroom. This elegant home combines classic charm with modern amenities.
#
# ---
#
# for hosting dinner parties. The gourmet kitchen features high-end appliances and a breakfast nook overlooking the landscaped backyard. Retreat to the luxurious master suite with a private balcony and spa-like bathroom. This elegant home combines classic charm with modern amenities.
#
# ---
#
# a gourmet kitchen, and a spacious dining area. The master suite includes a spa-like bathroom and walk-in closet. Relax on the private balcony with stunning views of the city skyline and waterfront.
#
#
# -----
#
# Answer the question : A comfortable three-bedroom house with a spacious kitchen and a cozy living room.
#
# Response: Based on the context given, the comfortable three-bedroom house with a spacious kitchen and cozy living room does not seem to have the same luxurious and elegant features mentioned in the original text.
# Sources: ['2', '2', '9']

# %%
AUGMENT_PROMPT_TEMPLATE =\
"""
Based on the following context:

{context}

---

craft a response that not only answers the question {question}, but also ensures that your explanation is distinct, captivating, and customized to align with the specified preferences. This involves subtly emphasizing aspects of the property that align with what the buyer is looking for.
"""

# %%
predict_response(query_text, AUGMENT_PROMPT_TEMPLATE)
# Out:
# Generated Prompt:
# Human:
# Based on the following context:
#
# for hosting dinner parties. The gourmet kitchen features high-end appliances and a breakfast nook overlooking the landscaped backyard. Retreat to the luxurious master suite with a private balcony and spa-like bathroom. This elegant home combines classic charm with modern amenities.
#
# ---
#
# for hosting dinner parties. The gourmet kitchen features high-end appliances and a breakfast nook overlooking the landscaped backyard. Retreat to the luxurious master suite with a private balcony and spa-like bathroom. This elegant home combines classic charm with modern amenities.
#
# ---
#
# a gourmet kitchen, and a spacious dining area. The master suite includes a spa-like bathroom and walk-in closet. Relax on the private balcony with stunning views of the city skyline and waterfront.
#
# ---
#
# craft a response that not only answers the question A comfortable three-bedroom house with a spacious kitchen and a cozy living room., but also ensures that your explanation is distinct, captivating, and customized to align with the specified preferences. This involves subtly emphasizing aspects of the property that align with what the buyer is looking for.
#
# Response: Absolutely! This beautiful three-bedroom house boasts a spacious gourmet kitchen, perfect for hosting dinner parties and entertaining guests. The cozy living room provides a warm and welcoming atmosphere for relaxing with family and friends. The master suite features a luxurious spa-like bathroom and a walk-in closet for added convenience. And let's not forget the private balcony with stunning views of the city skyline and waterfront, providing the perfect retreat after a long day. This charming home effortlessly combines classic charm with modern amenities, making it the ideal choice for those seeking comfort and style.
# Sources: ['2', '2', '9']

# %%
pip freeze > requirements.txt
