# %%
# Install pandas
# !pip install --quiet pandas

# %% [markdown]
# # STEP 1: SETUP OPENAI API KEY AND BASE

# %%
# All import statements used in the Step
import openai
import os

# %%
os.environ["OPENAI_API_KEY"] = "voc-1682785691266774337744690b15dbca9a82.58870878"
os.environ["OPENAI_API_BASE"] = "https://openai.vocareum.com/v1"

# %%
openai.api_key = os.getenv("OPENAI_API_KEY")
openai.api_base = os.getenv("OPENAI_API_BASE")

# %%
# GPT model used throughout the project
MODEL = "gpt-3.5-turbo"

# %% [markdown]
# # STEP 2: CREATE THE REAL ESTATE LISTINGS FOR THE CSV

# %%
# All import statements used in this Step
from pydantic import BaseModel, Field, NonNegativeInt
from typing import List
from langchain.output_parsers import PydanticOutputParser
from langchain.prompts import PromptTemplate

# %%
# Example Instruction and Sample
INSTRUCTION = "Generate a CSV file with at least 10 real estate listing."
SAMPLE_LISTING = \
"""
Neighborhood: Green Oaks
Price: $800,000
Bedrooms: 3
Bathrooms: 2
House Size: 2,000 sqft

Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.

Neighborhood Description: Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze.
"""

# %%
class RealEstates(BaseModel):
    neighborhood: str = Field(description="The neighborhood in which the property is located.")
    price: NonNegativeInt = Field(description="The price of the property in USD.")
    bedrooms: NonNegativeInt = Field(description="The number of bedrooms in the property.")
    bathrooms: NonNegativeInt = Field(description="The number of bathrooms in the property.")
    house_size: NonNegativeInt = Field(description="The size of the property in sqft.")
    description: str = Field(description="A brief description of the house describing all of its pros.")
    neighborhood_description: str = Field(description="A brief description of the neighborhood describing all of its pros.")

# %%
class Listings(BaseModel):
    listings: List[RealEstates] = Field(description="A list containing Real Estate details.")

# %%
parser = PydanticOutputParser(pydantic_object=Listings)

# %%
prompt_template = PromptTemplate(
    template="{instruction}\n{sample}\n{format_instructions}",
    input_variables=["instruction", "sample"],
    partial_variables={"format_instructions": parser.get_format_instructions}
)

print(prompt_template)
# Out:
# input_variables=['instruction', 'sample'] partial_variables={'format_instructions': <bound method PydanticOutputParser.get_format_instructions of PydanticOutputParser(pydantic_object=<class '__main__.Listings'>)>} template='{instruction}\n{sample}\n{format_instructions}'

# %%
initial_query = prompt_template.format(instruction=INSTRUCTION, sample=SAMPLE_LISTING)
print(initial_query)
# Out:
# Generate a CSV file with at least 10 real estate listing.
#
# Neighborhood: Green Oaks
# Price: $800,000
# Bedrooms: 3
# Bathrooms: 2
# House Size: 2,000 sqft
#
# Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.
#
# Neighborhood Description: Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze.
#
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"properties": {"listings": {"title": "Listings", "description": "A list containing Real Estate details.", "type": "array", "items": {"$ref": "#/definitions/RealEstates"}}}, "required": ["listings"], "definitions": {"RealEstates": {"title": "RealEstates", "type": "object", "properties": {"neighborhood": {"title": "Neighborhood", "description": "The neighborhood in which the property is located.", "type": "string"}, "price": {"title": "Price", "description": "The price of the property in USD.", "minimum": 0, "type": "integer"}, "bedrooms": {"title": "Bedrooms", "description": "The number of bedrooms in the property.", "minimum": 0, "type": "integer"}, "bathrooms": {"title": "Bathrooms", "description": "The number of bathrooms in the property.", "minimum": 0, "type": "integer"}, "house_size": {"title": "House Size", "description": "The size of the property in sqft.", "minimum": 0, "type": "integer"}, "description": {"title": "Description", "description": "A brief description of the house describing all of its pros.", "type": "string"}, "neighborhood_description": {"title": "Neighborhood Description", "description": "A brief description of the neighborhood describing all of its pros.", "type": "string"}}, "required": ["neighborhood", "price", "bedrooms", "bathrooms", "house_size", "description", "neighborhood_description"]}}}
# ```

# %%
llm_response = openai.ChatCompletion.create(
    model=MODEL,
    temperature=0.0,
    messages=[
        {
            "role": "user",
            "content": initial_query
        }
    ]
)

# %%
response_content = llm_response.choices[0].message.content
print(response_content)
# Out:
# {
#   "listings": [
#     {
#       "neighborhood": "Green Oaks",
#       "price": 800000,
#       "bedrooms": 3,
#       "bathrooms": 2,
#       "house_size": 2000,
#       "description": "Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.",
#       "neighborhood_description": "Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze."
#     },
#     {
#       "neighborhood": "Sunnyvale",
#       "price": 950000,
#       "bedrooms": 4,
#       "bathrooms": 3,
#       "house_size": 2500,
#       "description": "Beautiful 4-bedroom, 3-bathroom home located in the desirable neighborhood of Sunnyvale. This spacious home features a gourmet kitchen, luxurious master suite, and a backyard oasis with a pool and spa. Perfect for entertaining or relaxing with family, this home offers the best of indoor and outdoor living.",
#       "neighborhood_description": "Sunnyvale is known for its top-rated schools, vibrant downtown area, and easy access to major tech companies. Enjoy the sunny weather and community events throughout the year in this family-friendly neighborhood."
#     },
#     {
#       "neighborhood": "Willow Glen",
#       "price": 1200000,
#       "bedrooms": 5,
#       "bathrooms": 4,
#       "house_size": 3500,
#       "description": "Luxurious 5-bedroom, 4-bathroom estate in the prestigious neighborhood of Willow Glen. This custom-built home features high-end finishes, a gourmet kitchen, and a private backyard with a built-in BBQ and fire pit. With a spacious floor plan and elegant design, this home is perfect for those who appreciate the finer things in life.",
#       "neighborhood_description": "Willow Glen is known for its tree-lined streets, historic architecture, and upscale shopping and dining options. Enjoy the charm and character of this sought-after neighborhood while being just minutes away from downtown San Jose."
#     },
#     {
#       "neighborhood": "Los Gatos",
#       "price": 1800000,
#       "bedrooms": 4,
#       "bathrooms": 3,
#       "house_size": 3000,
#       "description": "Stunning 4-bedroom, 3-bathroom home in the exclusive neighborhood of Los Gatos. This recently renovated home features a chef's kitchen, luxurious master suite, and a beautifully landscaped backyard with a pool and spa. With high-end finishes and attention to detail throughout, this home offers luxury living at its finest.",
#       "neighborhood_description": "Los Gatos is known for its upscale shops, gourmet restaurants, and picturesque views of the Santa Cruz Mountains. Enjoy the small-town charm and vibrant community events in this desirable Silicon Valley neighborhood."
#     },
#     {
#       "neighborhood": "Palo Alto",
#       "price": 2500000,
#       "bedrooms": 6,
#       "bathrooms": 5,
#       "house_size": 4000,
#       "description": "Modern 6-bedroom, 5-bathroom home in the prestigious neighborhood of Palo Alto. This newly constructed home features a sleek design, high-tech amenities, and a rooftop deck with panoramic views. With a spacious layout and state-of-the-art features, this home is perfect for those who appreciate contemporary luxury.",
#       "neighborhood_description": "Palo Alto is known for its top-rated schools, world-class dining, and proximity to major tech companies. Experience the best of Silicon Valley living in this vibrant and innovative community."
#     },
#     {
#       "neighborhood": "Mountain View",
#       "price": 1500000,
#       "bedrooms": 4,
#       "bathrooms": 3,
#       "house_size": 2800,
#       "description": "Charming 4-bedroom, 3-bathroom home in the desirable neighborhood of Mountain View. This updated home features a gourmet kitchen, spacious living areas, and a private backyard with a deck and garden. With a warm and inviting atmosphere, this home is perfect for those who value comfort and style.",
#       "neighborhood_description": "Mountain View is known for its vibrant downtown, outdoor recreation options, and easy access to major tech companies. Enjoy the laid-back atmosphere and community events in this family-friendly neighborhood."
#     },
#     {
#       "neighborhood": "Cupertino",
#       "price": 1700000,
#       "bedrooms": 5,
#       "bathrooms": 4,
#       "house_size": 3200,
#       "description": "Spacious 5-bedroom, 4-bathroom home in the sought-after neighborhood of Cupertino. This well-maintained home features a flexible floor plan, updated kitchen, and a backyard oasis with a pool and spa. With plenty of space for work and play, this home is perfect for growing families or those who love to entertain.",
#       "neighborhood_description": "Cupertino is known for its top-rated schools, beautiful parks, and proximity to major tech companies. Experience the best of Silicon Valley living in this family-friendly and diverse community."
#     },
#     {
#       "neighborhood": "Menlo Park",
#       "price": 2200000,
#       "bedrooms": 4,
#       "bathrooms": 3,
#       "house_size": 3500,
#       "description": "Elegant 4-bedroom, 3-bathroom home in the prestigious neighborhood of Menlo Park. This classic home features a formal living room, gourmet kitchen, and a beautifully landscaped backyard with a patio and BBQ area. With timeless design and modern amenities, this home offers a perfect blend of comfort and sophistication.",
#       "neighborhood_description": "Menlo Park is known for its tree-lined streets, upscale shops, and proximity to Stanford University. Enjoy the peaceful atmosphere and community events in this upscale Silicon Valley neighborhood."
#     },
#     {
#       "neighborhood": "Saratoga",
#       "price": 2800000,
#       "bedrooms": 5,
#       "bathrooms": 4,
#       "house_size": 4000,
#       "description": "Luxurious 5-bedroom, 4-bathroom estate in the prestigious neighborhood of Saratoga. This custom-built home features high-end finishes, a gourmet kitchen, and a private backyard with a pool and spa. With a spacious floor plan and elegant design, this home is perfect for those who appreciate the finer things in life.",
#       "neighborhood_description": "Saratoga is known for its upscale shops, gourmet restaurants, and picturesque views of the Santa Cruz Mountains. Enjoy the small-town charm and vibrant community events in this desirable Silicon Valley neighborhood."
#     },
#     {
#       "neighborhood": "Los Altos",
#       "price": 2000000,
#       "bedrooms": 4,
#       "bathrooms": 3,
#       "house_size": 3500,
#       "description": "Stunning 4-bedroom, 3-bathroom home in the exclusive neighborhood of Los Altos. This recently renovated home features a chef's kitchen, luxurious master suite, and a beautifully landscaped backyard with a pool and spa. With high-end finishes and attention to detail throughout, this home offers luxury living at its finest.",
#       "neighborhood_description": "Los Altos is known for its upscale shops, gourmet restaurants, and picturesque views of the Santa Cruz Mountains. Enjoy the small-town charm and vibrant community events in this desirable Silicon Valley neighborhood."
#     }
#   ]
# }

# %% [markdown]
# # STEP 3: CREATE THE CSV FROM THE LISTINGS

# %%
# All import statements used in this step
import pandas as pd

# %%
parsed_content = parser.parse(response_content)

# %%
listings = parsed_content.listings

# %%
df = pd.DataFrame([listing.dict() for listing in listings])
df.head()
# Out:
#   neighborhood    price  bedrooms  bathrooms  house_size  \
# 0   Green Oaks   800000         3          2        2000
# 1    Sunnyvale   950000         4          3        2500
# 2  Willow Glen  1200000         5          4        3500
# 3    Los Gatos  1800000         4          3        3000
# 4    Palo Alto  2500000         6          5        4000
#
#                                          description  \
# 0  Welcome to this eco-friendly oasis nestled in ...
# 1  Beautiful 4-bedroom, 3-bathroom home located i...
# 2  Luxurious 5-bedroom, 4-bathroom estate in the ...
# 3  Stunning 4-bedroom, 3-bathroom home in the exc...
# 4  Modern 6-bedroom, 5-bathroom home in the prest...
#
#                             neighborhood_description
# 0  Green Oaks is a close-knit, environmentally-co...
# 1  Sunnyvale is known for its top-rated schools, ...
# 2  Willow Glen is known for its tree-lined street...
# 3  Los Gatos is known for its upscale shops, gour...
# 4  Palo Alto is known for its top-rated schools, ...

# %%
df.to_csv("Real_Estates.csv")

# %% [markdown]
# # STEP 4: CREATE THE CHROMA DB VECTOR DATABASE

# %%
# All import statements used in this step
import pandas as pd
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.schema import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma

# %%
import shutil
import os

if os.path.exists(CHROMA_PATH):
    shutil.rmtree(CHROMA_PATH)

# %%
df = pd.read_csv("Real_Estates.csv")

# %%
CHROMA_PATH = "content/chroma"

# %%
embedding_function = OpenAIEmbeddings()

# %%
documents = []
for index, row in df.iterrows():
    documents.append(Document(page_content=row["description"], metadata={"id": str(index)}))
print(f"Successfully created {len(documents)} documents from CSV.")
# Out:
# Successfully created 10 documents from CSV.

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=300,
    chunk_overlap=100,
    length_function=len,
    add_start_index=True
)

# %%
chunks = text_splitter.split_documents(documents)
print(f"Successfully created {len(chunks)} chunks from {len(documents)} documents.")
# Out:
# Successfully created 20 chunks from 10 documents.

# %%
if os.path.exists(CHROMA_PATH):
    shutil.rmtree(CHROMA_PATH)

# %%
db = Chroma.from_documents(
    documents=chunks,
    embedding=embedding_function,
    persist_directory=CHROMA_PATH
)

# %%
db.persist()
print(f"Successfully created ChromaDB Vector Database at {CHROMA_PATH}")
# Out:
# Successfully created ChromaDB Vector Database at content/chroma

# %% [markdown]
# # STEP 5: SEMANTIC SEARCH USING USER INPUT

# %%
# All Import statements used in this step
from langchain.prompts import ChatPromptTemplate

# %%
user_query = input("Describe your dream house: ")
# Out:
# Describe your dream house: A comfortable three-bedroom house with a spacious kitchen and a cozy living room.

# %%
BASIC_PROMPT_TEMPLATE = """
Based on the following context:

{context}

---

Answer the following question: {question}
"""

# %%
def semantic_search(question, template):
    db = Chroma(
        persist_directory=CHROMA_PATH,
        embedding_function=embedding_function
    )
    
    top_3 = db.similarity_search_with_relevance_scores(query=question, k=3)
    if len(top_3) == 0 or top_3[0][1] < 0.7:
        print("Unable to find relevant matches!")
        return
    else:
        context_text = "\n----\n".join([doc.page_content for doc, _score in top_3])
        prompt_template = PromptTemplate(
            template=template,
            input_variables=["context", "question"]
        )
        prompt = prompt_template.format(context=context_text, question=question)
        print(f"Generated Prompt:\n{prompt}")
        return prompt

# %%
result = semantic_search(question=user_query, template=BASIC_PROMPT_TEMPLATE)
# Out:
# Generated Prompt:
#
# Based on the following context:
#
# With a spacious layout and state-of-the-art features, this home is perfect for those who appreciate contemporary luxury.
# ----
# BBQ area. With timeless design and modern amenities, this home offers a perfect blend of comfort and sophistication.
# ----
# With plenty of space for work and play, this home is perfect for growing families or those who love to entertain.
#
# ---
#
# Answer the following question: A comfortable three-bedroom house with a spacious kitchen and a cozy living room.

# %%
llm_response = openai.ChatCompletion.create(
    model=MODEL,
    temperature=0.0,
    messages=[
        {
            "role": "user",
            "content": result
        }
    ]
)

# %%
print(llm_response.choices[0].message.content)
# Out:
# This home would be perfect for those who value comfort and functionality in their living space.

# %% [markdown]
# ### AUGMENTING SEARCH USING SYSTEM PROMPT

# %%
system_prompt = """
You are LLMRealtor, a highly experienced Real Estate Agent who has sold hundreds of properties.
You are polite, warm and friendly.
You will be given a three Real Estates that are the closest to a buyer's preferences.
Your task is to positively convince them that these three properties are the best for them and give them proper reasons to buy one of these properties. 
**Ultimately, suggest the best property according to the *buyer's preferences* provided.**
"""

# %%
AUGMENTED_PROMPT = """
REAL ESTATES CLOSEST TO THE BUYER'S PREFERENCES:

{context}

---

BUYER'S ORIGINAL PREFERENCE: {question}
"""

# %%
result = semantic_search(question=user_query, template=AUGMENTED_PROMPT)
# Out:
# Generated Prompt:
#
# REAL ESTATES CLOSEST TO THE BUYER'S PREFERENCES:
#
# With a spacious layout and state-of-the-art features, this home is perfect for those who appreciate contemporary luxury.
# ----
# BBQ area. With timeless design and modern amenities, this home offers a perfect blend of comfort and sophistication.
# ----
# With plenty of space for work and play, this home is perfect for growing families or those who love to entertain.
#
# ---
#
# BUYER'S ORIGINAL PREFERENCE: A comfortable three-bedroom house with a spacious kitchen and a cozy living room.

# %%
llm_response = openai.ChatCompletion.create(
    model=MODEL,
    temperature=0.7,
    messages=[
        {
            "role": "system",
            "content": system_prompt
        },
        {
            "role": "user",
            "content": result
        }
    ]
)

# %%
print(llm_response.choices[0].message.content)
# Out:
# Hello! I hope you're having a great day. I've found three wonderful properties that closely match your preferences for a comfortable three-bedroom house with a spacious kitchen and a cozy living room. Let me introduce you to the options:
#
# 1. The first property boasts a spacious layout and state-of-the-art features, perfect for those who appreciate contemporary luxury. The large kitchen is ideal for preparing meals and entertaining guests, while the cozy living room provides a warm and inviting space to relax and unwind after a long day.
#
# 2. The second property features a BBQ area and offers a perfect blend of comfort and sophistication with its timeless design and modern amenities. The three bedrooms provide ample space for your family or guests, and the spacious kitchen is sure to inspire your culinary creations.
#
# 3. The third property is great for growing families or those who love to entertain, with plenty of space for work and play. The three bedrooms offer versatility for your needs, while the cozy living room provides a welcoming atmosphere for gatherings with loved ones.
#
# Considering your preference for a comfortable three-bedroom house with a spacious kitchen and a cozy living room, I would recommend the third property with plenty of space for work and play. It seems to align best with your needs for a cozy living room while also offering ample space for your family and any entertaining you may do. Would you like to explore this property further or do you have any specific questions?
