# %%
# Import Statements

import os
import openai
from pydantic import BaseModel, Field, NonNegativeInt
from typing import List, Optional
from langchain.output_parsers import PydanticOutputParser
from langchain.prompts import PromptTemplate
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# # STEP 0: INITIALIZE THE LLM

# %%
os.environ["OPENAI_API_KEY"] = "voc-176713170812667743680626901c4a6b06bd0.19164315"
os.environ["OPENAI_API_BASE"] = "https://openai.vocareum.com/v1"

# %%
# Select the LLM Model
MODEL = "gpt-3.5-turbo"

# %%
# Initialze the LLM client
openai.api_key=os.getenv("OPENAI_API_KEY")
openai.api_base=os.getenv("OPENAI_API_BASE")

# %% [markdown]
# ## STEP 1: CREATE THE CSV

# %%
# Example Instruction and Sample
INSTRUCTION = "Generate a CSV file with at least 10 real estate listing."
SAMPLE_LISTING = \
"""
Neighborhood: Green Oaks
Price: $800,000
Bedrooms: 3
Bathrooms: 2
House Size: 2,000 sqft

Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.

Neighborhood Description: Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze.
"""

# %%
# Create the RealEstate Class
class RealEstate(BaseModel):
    Neighborhood: str = Field(description="The neighborhood where the property is located")
    price: NonNegativeInt = Field(description="THe price of the property in USD")
    bedrooms: NonNegativeInt = Field(description="The number of bedrooms in the property")
    bathrooms: NonNegativeInt = Field(description="The number of bathrooms in the property")
    house_size: NonNegativeInt = Field(description="The size of the house in square feet")
    description: str = Field(description="A description of the property")
    neighborhood_description: str = Field(description="A description of the neighborhood")

# %%
class Listings(BaseModel):
    listings: List[RealEstate] = Field(description="A list containing real estates.")

# %%
# Create the parser
parser = PydanticOutputParser(pydantic_object=Listings)

# %%
# Initialize the Prompt Template
prompt_template = PromptTemplate(
    template="{instruction}\n{sample}\n{format_instructions}",
    input_variables=["instruction", "sample"],
    partial_variables={"format_instructions": parser.get_format_instructions}
)

print(prompt_template)
# Out:
# input_variables=['instruction', 'sample'] partial_variables={'format_instructions': <bound method PydanticOutputParser.get_format_instructions of PydanticOutputParser(pydantic_object=<class '__main__.Listings'>)>} template='{instruction}\n{sample}\n{format_instructions}'

# %%
# Create the inital query
initial_query = prompt_template.format(instruction=INSTRUCTION, sample=SAMPLE_LISTING)

print(initial_query)
# Out:
# Generate a CSV file with at least 10 real estate listing.
#
# Neighborhood: Green Oaks
# Price: $800,000
# Bedrooms: 3
# Bathrooms: 2
# House Size: 2,000 sqft
#
# Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.
#
# Neighborhood Description: Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze.
#
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"properties": {"listings": {"title": "Listings", "description": "A list containing real estates.", "type": "array", "items": {"$ref": "#/definitions/RealEstate"}}}, "required": ["listings"], "definitions": {"RealEstate": {"title": "RealEstate", "type": "object", "properties": {"Neighborhood": {"title": "Neighborhood", "description": "The neighborhood where the property is located", "type": "string"}, "price": {"title": "Price", "description": "THe price of the property in USD", "minimum": 0, "type": "integer"}, "bedrooms": {"title": "Bedrooms", "description": "The number of bedrooms in the property", "minimum": 0, "type": "integer"}, "bathrooms": {"title": "Bathrooms", "description": "The number of bathrooms in the property", "minimum": 0, "type": "integer"}, "house_size": {"title": "House Size", "description": "The size of the house in square feet", "minimum": 0, "type": "integer"}, "description": {"title": "Description", "description": "A description of the property", "type": "string"}, "neighborhood_description": {"title": "Neighborhood Description", "description": "A description of the neighborhood", "type": "string"}}, "required": ["Neighborhood", "price", "bedrooms", "bathrooms", "house_size", "description", "neighborhood_description"]}}}
# ```

# %%
# Get the LLM Response
response = openai.ChatCompletion.create(
    model=MODEL,
    temperature=0.0,
    messages=[
        {
            "role": "user",
            "content": initial_query
        }
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# {
#   "listings": [
#     {
#       "Neighborhood": "Green Oaks",
#       "price": 800000,
#       "bedrooms": 3,
#       "bathrooms": 2,
#       "house_size": 2000,
#       "description": "Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.",
#       "neighborhood_description": "Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze."
#     },
#     {
#       "Neighborhood": "Sunnyvale",
#       "price": 950000,
#       "bedrooms": 4,
#       "bathrooms": 3,
#       "house_size": 2500,
#       "description": "Located in the desirable neighborhood of Sunnyvale, this 4-bedroom, 3-bathroom home offers spacious living areas and a beautifully landscaped backyard. The updated kitchen features stainless steel appliances and granite countertops, perfect for entertaining guests. Enjoy the California sunshine in the private backyard oasis with a sparkling pool and outdoor kitchen. This home is perfect for families looking for a blend of comfort and luxury.",
#       "neighborhood_description": "Sunnyvale is known for its top-rated schools, vibrant downtown area, and easy access to major tech companies. Residents can enjoy hiking and biking trails at nearby parks or explore the local farmers' market for fresh produce and artisan goods."
#     },
#     {
#       "Neighborhood": "Brooklyn Heights",
#       "price": 1200000,
#       "bedrooms": 5,
#       "bathrooms": 4,
#       "house_size": 3500,
#       "description": "Welcome to this stunning 5-bedroom, 4-bathroom home in the historic neighborhood of Brooklyn Heights. This elegant brownstone features high ceilings, original hardwood floors, and period details throughout. The gourmet kitchen is a chef's dream with top-of-the-line appliances and custom cabinetry. Relax in the private backyard garden or unwind on the rooftop terrace with panoramic views of the city skyline. Experience luxury living in the heart of Brooklyn.",
#       "neighborhood_description": "Brooklyn Heights is a picturesque neighborhood known for its tree-lined streets, historic architecture, and waterfront promenade. Residents can enjoy boutique shopping, fine dining, and cultural attractions within walking distance. With easy access to public transportation, Manhattan is just a short commute away."
#     },
#     {
#       "Neighborhood": "Pacific Palisades",
#       "price": 3500000,
#       "bedrooms": 6,
#       "bathrooms": 5,
#       "house_size": 5000,
#       "description": "Situated in the prestigious neighborhood of Pacific Palisades, this 6-bedroom, 5-bathroom estate offers luxury living at its finest. The grand foyer leads to a formal living room with a fireplace and a spacious dining area perfect for hosting dinner parties. The gourmet kitchen features high-end appliances and a large center island. The expansive backyard oasis includes a pool, spa, and outdoor kitchen, ideal for entertaining guests. Experience the epitome of California coastal living in this Pacific Palisades masterpiece.",
#       "neighborhood_description": "Pacific Palisades is a sought-after community with upscale shopping, dining, and outdoor recreational activities. Residents can enjoy hiking trails in the nearby Santa Monica Mountains or relax on the sandy beaches of the Pacific Ocean. With top-rated schools and a strong sense of community, Pacific Palisades offers a luxurious yet laid-back lifestyle."
#     },
#     {
#       "Neighborhood": "South Beach",
#       "price": 2000000,
#       "bedrooms": 3,
#       "bathrooms": 3,
#       "house_size": 2200,
#       "description": "Welcome to this modern 3-bedroom, 3-bathroom condo in the vibrant neighborhood of South Beach. The open floor plan features floor-to-ceiling windows, sleek finishes, and stunning views of the city skyline. The gourmet kitchen is equipped with high-end appliances and a breakfast bar. Relax on the private balcony or take advantage of the building's amenities, including a fitness center and rooftop pool. Live in the heart of San Francisco's most exciting neighborhood.",
#       "neighborhood_description": "South Beach is a dynamic neighborhood known for its waterfront location, trendy restaurants, and cultural attractions. Residents can explore the nearby Embarcadero waterfront, visit the Ferry Building Marketplace, or catch a Giants game at Oracle Park. With easy access to public transportation and tech shuttles, commuting is convenient and stress-free."
#     },
#     {
#       "Neighborhood": "Beverly Hills",
#       "price": 5000000,
#       "bedrooms": 7,
#       "bathrooms": 6,
#       "house_size": 8000,
#       "description": "Experience luxury living in this magnificent 7-bedroom, 6-bathroom estate in the prestigious neighborhood of Beverly Hills. The grand foyer leads to a formal living room with a fireplace and a formal dining room with custom millwork. The gourmet kitchen features top-of-the-line appliances, a large center island, and a breakfast nook. The expansive backyard offers a pool, spa, outdoor kitchen, and lush landscaping, perfect for entertaining guests. Live the Beverly Hills lifestyle in this exquisite estate.",
#       "neighborhood_description": "Beverly Hills is synonymous with luxury, offering upscale shopping, fine dining, and world-class entertainment. Residents can explore Rodeo Drive, visit iconic landmarks like the Beverly Hills Hotel, or relax in one of the city's beautiful parks. With top-rated schools and a strong sense of community, Beverly Hills is a highly desirable place to call home."
#     },
#     {
#       "Neighborhood": "Tribeca",
#       "price": 3000000,
#       "bedrooms": 4,
#       "bathrooms": 3,
#       "house_size": 2800,
#       "description": "Located in the trendy neighborhood of Tribeca, this 4-bedroom, 3-bathroom loft offers a blend of industrial chic and modern luxury. The open floor plan features exposed brick walls, high ceilings, and oversized windows that flood the space with natural light. The chef's kitchen is equipped with high-end appliances and a large center island. Enjoy the convenience of a private elevator and the building's amenities, including a fitness center and rooftop terrace. Live in style in the heart of downtown Manhattan.",
#       "neighborhood_description": "Tribeca is a vibrant neighborhood known for its cobblestone streets, art galleries, and celebrity residents. Residents can explore the area's trendy boutiques, dine at world-class restaurants, or attend film screenings at the Tribeca Film Festival. With easy access to public transportation and cultural attractions, Tribeca offers a dynamic urban lifestyle."
#     },
#     {
#       "Neighborhood": "Malibu",
#       "price": 10000000,
#       "bedrooms": 8,
#       "bathrooms": 7,
#       "house_size": 10000,
#       "description": "Perched on a cliff overlooking the Pacific Ocean, this 8-bedroom, 7-bathroom estate offers unparalleled luxury in the exclusive neighborhood of Malibu. The grand foyer leads to a formal living room with a fireplace and a formal dining room with ocean views. The gourmet kitchen features top-of-the-line appliances, a large center island, and a breakfast nook. The expansive outdoor space includes a pool, spa, outdoor kitchen, and private beach access. Live the Malibu dream in this breathtaking oceanfront estate.",
#       "neighborhood_description": "Malibu is a world-renowned beach community known for its stunning coastline, celebrity residents, and upscale amenities. Residents can enjoy surfing at world-class beaches, hiking in the Santa Monica Mountains, or dining at chic restaurants along the Pacific Coast Highway. With a laid-back vibe and luxurious lifestyle, Malibu offers a unique blend of natural beauty and sophistication."
#     },
#     {
#       "Neighborhood": "Georgetown",
#       "price": 1500000,
#       "bedrooms": 6,
#       "bathrooms": 4,
#       "house_size": 4000,
#       "description": "Welcome to this elegant 6-bedroom, 4-bathroom townhouse in the historic neighborhood of Georgetown. This Federal-style home features original architectural details, hardwood floors, and multiple fireplaces. The gourmet kitchen is equipped with high-end appliances and custom cabinetry. Relax in the private courtyard garden or entertain guests in the formal dining room. Live in sophistication and style in this Georgetown gem.",
#       "neighborhood_description": "Georgetown is a charming neighborhood known for its cobblestone streets, historic architecture, and upscale shopping. Residents can explore the area's boutique shops, dine at award-winning restaurants, or visit cultural landmarks like the Georgetown Waterfront Park. With a strong sense of community and easy access to public transportation, Georgetown offers a refined urban lifestyle."
#     },
#     {
#       "Neighborhood": "Palm Springs",
#       "price": 700000,
#       "bedrooms": 2,
#       "bathrooms": 2,
#       "house_size": 1800,
#       "description": "Escape to this stylish 2-bedroom, 2-bathroom retreat in the desert oasis of Palm Springs. The open-concept living space features vaulted ceilings, polished concrete floors, and a cozy fireplace. The gourmet kitchen is equipped with stainless steel appliances and quartz countertops. Relax in the private backyard with a pool, spa, and mountain views. Experience the ultimate relaxation in this Palm Springs paradise.",
#       "neighborhood_description": "Palm Springs is a resort city known for its mid-century modern architecture, hot springs, and vibrant arts scene. Residents can enjoy golfing, hiking, and shopping in the downtown area, or attend cultural events like the Palm Springs International Film Festival. With year-round sunshine and a laid-back atmosphere, Palm Springs offers a peaceful retreat from city life."
#     }
#   ]
# }

# %%
# Parse the LLM Response using the parser
response_content = response.choices[0].message.content
parsed_content = parser.parse(response_content)

# %%
# Create the DataFrame from the Parsed Content
listings = parsed_content.listings
df = pd.DataFrame([listing.dict() for listing in listings])
df.head()
# Out:
#         Neighborhood    price  bedrooms  bathrooms  house_size  \
# 0         Green Oaks   800000         3          2        2000
# 1          Sunnyvale   950000         4          3        2500
# 2   Brooklyn Heights  1200000         5          4        3500
# 3  Pacific Palisades  3500000         6          5        5000
# 4        South Beach  2000000         3          3        2200
#
#                                          description  \
# 0  Welcome to this eco-friendly oasis nestled in ...
# 1  Located in the desirable neighborhood of Sunny...
# 2  Welcome to this stunning 5-bedroom, 4-bathroom...
# 3  Situated in the prestigious neighborhood of Pa...
# 4  Welcome to this modern 3-bedroom, 3-bathroom c...
#
#                             neighborhood_description
# 0  Green Oaks is a close-knit, environmentally-co...
# 1  Sunnyvale is known for its top-rated schools, ...
# 2  Brooklyn Heights is a picturesque neighborhood...
# 3  Pacific Palisades is a sought-after community ...
# 4  South Beach is a dynamic neighborhood known fo...

# %%
# Save the DataFrame to a CSV
df.to_csv("Real_Estates.csv")

# %% [markdown]
# ## STEP 2: CREATING THE VECTOR DATABASE USING TF-IDF

# %%
# Read the CSV
df = pd.read_csv("Real_Estates.csv")

# %%
def document(raw):
    """Convert the listings into text representation for TF-IDF"""
    return " ".join([
        f"""
            \nNeigborhood: {str(raw["Neighborhood"])}
            \nPrice: ${str(raw["price"])}
            \nBedrooms: {str(raw["bedrooms"])}
            \nBathrooms: {str(raw["bathrooms"])}
            \nHouse Size: {str(raw["house_size"])}
            \nProperty Description: {str(raw["description"])}
            \nNeighborhood Description: {str(raw["neighborhood_description"])}
        """
    ])

# %%
documents_from_csv = [document(row) for _, row in df.iterrows()]
print(documents_from_csv[1])
# Out:
#
# Neigborhood: Sunnyvale
#
# Price: $950000
#
# Bedrooms: 4
#
# Bathrooms: 3
#
# House Size: 2500
#
# Property Description: Located in the desirable neighborhood of Sunnyvale, this 4-bedroom, 3-bathroom home offers spacious living areas and a beautifully landscaped backyard. The updated kitchen features stainless steel appliances and granite countertops, perfect for entertaining guests. Enjoy the California sunshine in the private backyard oasis with a sparkling pool and outdoor kitchen. This home is perfect for families looking for a blend of comfort and luxury.
#
# Neighborhood Description: Sunnyvale is known for its top-rated schools, vibrant downtown area, and easy access to major tech companies. Residents can enjoy hiking and biking trails at nearby parks or explore the local farmers' market for fresh produce and artisan goods.

# %%
# Initialize the Vectorizer and Fit the data
vectorizer = TfidfVectorizer(stop_words="english")
tfidf_matrix = vectorizer.fit_transform(documents_from_csv)

# %% [markdown]
# ## STEP 3: EXTRACTING THE USER PREFERENCES

# %%
# Define the Preference model
class Prefs:
    def __init__(self, budget, bedrooms, bathrooms, minimum_area, property_preferences, neighborhood_preferences):
        self.budget = budget or None,
        self.bedrooms = bedrooms or None,
        self.bathrooms = bathrooms or None,
        self.minimum_area = minimum_area or None,
        self.property_preferences = property_preferences or "",
        self.neighborhood_preferences = neighborhood_preferences or ""

# %%
# Take user input
print("Let us know about your dream property!")
budget = int(input("Enter your budget"))
bedrooms = int(input("How many bedrooms do you want?"))
bathrooms = int(input("How many bathrooms do you want?"))
minimum_area = int(input("How large of a house do you want (in sqft)?"))
property_preferences = input("Any preferences for the property?")
neighborhood_preferences = input("Any preferences for the neighborhood?")
# Out:
# Let us know about your dream property!
# Enter your budget800000
# How many bedrooms do you want?2
# How many bathrooms do you want?2
# How large of a house do you want (in sqft)?2000
# Any preferences for the property?
# Any preferences for the neighborhood?

# %%
prefs = Prefs(
    budget=budget, 
    bedrooms=bedrooms, 
    bathrooms=bathrooms,
    minimum_area=minimum_area,
    property_preferences=property_preferences,
    neighborhood_preferences=neighborhood_preferences
)

# %% [markdown]
# ## STEP 4: SEMANTIC SEARCH USING TF-IDF AND FILTERING

# %%
query = " ".join([
    f"${prefs.budget[0]}" if prefs.budget else "",
    f"{prefs.bedrooms[0]} bedrooms" if prefs.bedrooms else "",
    f"{prefs.bathrooms[0]} bathrooms" if prefs.bathrooms else "",
    f"{prefs.minimum_area[0]} sqft" if prefs.minimum_area else "",
    f"{prefs.property_preferences[0]}" if prefs.property_preferences else "",
    f"{prefs.neighborhood_preferences}" if prefs.property_preferences else ""
])

# %%
print(query)
# Out:
# $800000 2 bedrooms 2 bathrooms 2000 sqft

# %%
query_vec = vectorizer.transform([query])

# %%
scores = cosine_similarity(query_vec, tfidf_matrix)[0]

# %%
df["similarity"] = scores
ranked_df = df.sort_values(by="similarity", ascending=False)

# %%
ranked_df.head(1)
# Out:
#    Unnamed: 0 Neighborhood   price  bedrooms  bathrooms  house_size  \
# 0           0   Green Oaks  800000         3          2        2000
#
#                                          description  \
# 0  Welcome to this eco-friendly oasis nestled in ...
#
#                             neighborhood_description  similarity
# 0  Green Oaks is a close-knit, environmentally-co...    0.127948

# %%
filtered = []

for _, row in ranked_df.iterrows():
    ok = True

    price, bedrooms, bathrooms, size = int(row["price"]), int(row["bedrooms"]), int(row["bathrooms"]), int(row["house_size"])

    if prefs.budget and prefs.budget[0] < price:
        ok = False
    if prefs.bedrooms and prefs.bedrooms[0] > bedrooms:
        ok = False
    if prefs.bathrooms and prefs.bathrooms[0] > bathrooms:
        ok = False
    if prefs.minimum_area and prefs.minimum_area[0] > size:
        of = False

    if ok:
        filtered.append(row)

if not filtered:
    print("No matches found!")

# %% [markdown]
# ## STEP 5: PERSONALIZED RECOMMENDATION BY AN LLM

# %%
final_query = None

if filtered:
    best = filtered[0].drop("similarity").to_dict()

    final_query = f"""
    Here are the details of a property that is very similar to the preferences of a buyer:
    
    {best}

    ---

    You are LLMRealtor. Your task is to convince the buyer that this property is the best suited for them like a Real Estate Agent.
    Be very convincing using a warm, polite tone. Give them detailed introspection about the positive features of this property.
    """

print(final_query)
# Out:
#     Here are the details of a property that is very similar to the preferences of a buyer:
#
#     {'Unnamed: 0': 0, 'Neighborhood': 'Green Oaks', 'price': 800000, 'bedrooms': 3, 'bathrooms': 2, 'house_size': 2000, 'description': 'Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.', 'neighborhood_description': 'Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze.'}
#
#     ---
#
#     You are LLMRealtor. Your task is to convince the buyer that this property is the best suited for them like a Real Estate Agent.
#     Be very convincing using a warm, polite tone. Give them detailed introspection about the positive features of this property.

# %%
response = openai.ChatCompletion.create(
    model=MODEL,
    temperature=0.7,
    messages=[
        {
            "role": "user",
            "content": final_query
        }
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# Hello there,
#
# I am thrilled to present to you a property that truly embodies your eco-conscious lifestyle preferences. This charming home located in the heart of Green Oaks is a true gem that I believe will exceed your expectations.
#
# One of the standout features of this property is its energy-efficient design, with solar panels and a well-insulated structure that will not only reduce your carbon footprint but also save you money on energy bills. The abundance of natural light flowing through the living spaces showcases the beautiful hardwood floors and eco-conscious finishes, creating a warm and inviting atmosphere.
#
# The open-concept kitchen and dining area leading to a spacious backyard with a vegetable garden is the perfect setting for you to embrace sustainable living without compromising on style. Imagine growing your own organic produce right in your backyard, truly a dream for an eco-conscious family like yours.
#
# Moreover, the neighborhood of Green Oaks is a close-knit community that shares your environmental values. With access to organic grocery stores, community gardens, and bike paths, you will feel right at home in this environmentally-conscious environment. The nearby Green Oaks Park and Green Bean Cafe offer opportunities for relaxation and socializing, adding to the charm of the neighborhood.
#
# With easy access to public transportation and bike lanes, commuting will be a breeze for you. This property not only aligns with your values but also offers convenience and comfort that will enhance your quality of life.
#
# I truly believe that this property in Green Oaks is the perfect fit for you and your family. I would be more than happy to arrange a viewing for you to experience the eco-friendly oasis firsthand. Don't miss out on this opportunity to live in a home that reflects your values and lifestyle choices.
#
# Looking forward to hearing from you soon.
#
# Warm regards,
# LLMRealtor
