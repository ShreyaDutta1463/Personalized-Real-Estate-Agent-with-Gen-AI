# %%
# !pip install langchain-openai
# Out:
# Requirement already satisfied: langchain-openai in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (1.0.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.2 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langchain-openai) (1.0.4)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langchain-openai) (2.8.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (0.4.38)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.2->langchain-openai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (0.25.0)
# Requirement already satisfied: anyio in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (4.11.0)
# Requirement already satisfied: certifi in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.2->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.2->langchain-openai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.2->langchain-openai) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (2.3.0)
# Requirement already satisfied: colorama in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain-openai) (0.4.6)
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install langchain-text-splitters
# Out:
# Collecting langchain-text-splitters
#   Downloading langchain_text_splitters-1.0.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langchain-text-splitters) (1.0.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.4.38)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: anyio in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (4.11.0)
# Requirement already satisfied: certifi in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\shreya dutta\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.3.1)
# Downloading langchain_text_splitters-1.0.0-py3-none-any.whl (33 kB)
# Installing collected packages: langchain-text-splitters
# Successfully installed langchain-text-splitters-1.0.0
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install langchain-community

# %%
# All Import statements in one cell

import os
from langchain_openai import ChatOpenAI
from pydantic import BaseModel, Field, NonNegativeInt
from typing import List
from langchain_core.output_parsers import PydanticOutputParser
from langchain_core.prompts import PromptTemplate
import pandas as pd
from langchain_openai import OpenAIEmbeddings
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
import random
from langchain_community.vectorstores import LanceDB
from langchain_core.prompts import ChatPromptTemplate
import lancedb
import shutil
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 14
#      12 from langchain_text_splitters import RecursiveCharacterTextSplitter
#      13 import random
# ---> 14 from langchain_community.vectorstores import LanceDB
#      15 from langchain_core.prompts import ChatPromptTemplate
#      16 import lancedb
#
# ModuleNotFoundError: No module named 'langchain_community'

# %% [markdown]
# # SETTING UP THE ENVIRONMENT

# %%
# Initializing the API Base and Key

os.environ["OPENAI_API_BASE"] = "https://openai.vocareum.com/v1"
os.environ["OPENAI_API_KEY"] = "voc-176713170812667743680626901c4a6b06bd0.19164315"

# %%
# Choosing the LLM Model and Temperature

MODEL_NAME = "gpt-3.5-turbo"
MODEL_TEMPERATURE = 0.0

# %%
# Initializing the LLM

llm = ChatOpenAI(model=MODEL_NAME, temperature=MODEL_TEMPERATURE)

# %%
# Verify if the LLM has been set up correctly and responding to queries.

verify = llm.invoke("Hello!")
print(verify.content)
# Out:
# Hello! How can I assist you today?

# %% [markdown]
# # CREATING THE CSV DATA USING OUR LLM

# %%
# Example Instruction and Sample

INSTRUCTION = "Generate a CSV file with at least 10 real estate listing."
SAMPLE_LISTING = \
"""
Neighborhood: Green Oaks
Price: $800,000
Bedrooms: 3
Bathrooms: 2
House Size: 2,000 sqft

Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.

Neighborhood Description: Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze.
"""

# %%
# Creating the RealEstate class

class RealEstate(BaseModel):
    neighborhood: str = Field(description="The neighborhood in which the property is located.")
    price: NonNegativeInt = Field(description="The price of the property.")
    bedrooms: NonNegativeInt = Field(description="The number of bedrooms in the property. Should be a whole number.")
    bathrooms: NonNegativeInt = Field(description="The number of bathrooms in the property. Should be a whole number.")
    house_size: NonNegativeInt = Field(description="The size of the property in square feet. Should be a whole number.")
    description: str = Field(description="A detailed, evocative description of the property.")
    neighborhood_description: str = Field(description="A detailed, evocative description of the neighborhood in which the property is located.")

# %%
# Creating the Listings class

class Listings(BaseModel):
    listings: List[RealEstate] = Field(description="A list containing Real Estate details.")

# %%
# Setting up the parser

parser = PydanticOutputParser(pydantic_object=Listings)

# %%
# Setting up the prompt

prompt = PromptTemplate(
    template="{instruction}\n{sample}\n{format_instructions}\n",
    input_variables=["instruction", "sample"],
    partial_variables={"format_instructions": parser.get_format_instructions}
)

# %%
# Validate the prompt
print(prompt)
# Out:
# input_variables=['instruction', 'sample'] input_types={} partial_variables={'format_instructions': <bound method PydanticOutputParser.get_format_instructions of PydanticOutputParser(pydantic_object=<class '__main__.Listings'>)>} template='{instruction}\n{sample}\n{format_instructions}\n'

# %%
# Create the query

query = prompt.format(instruction=INSTRUCTION, sample=SAMPLE_LISTING)

# %%
# Validate the query
print(query)
# Out:
# Generate a CSV file with at least 10 real estate listing.
#
# Neighborhood: Green Oaks
# Price: $800,000
# Bedrooms: 3
# Bathrooms: 2
# House Size: 2,000 sqft
#
# Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.
#
# Neighborhood Description: Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze.
#
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"$defs": {"RealEstate": {"properties": {"neighborhood": {"description": "The neighborhood in which the property is located.", "title": "Neighborhood", "type": "string"}, "price": {"description": "The price of the property.", "minimum": 0, "title": "Price", "type": "integer"}, "bedrooms": {"description": "The number of bedrooms in the property. Should be a whole number.", "minimum": 0, "title": "Bedrooms", "type": "integer"}, "bathrooms": {"description": "The number of bathrooms in the property. Should be a whole number.", "minimum": 0, "title": "Bathrooms", "type": "integer"}, "house_size": {"description": "The size of the property in square feet. Should be a whole number.", "minimum": 0, "title": "House Size", "type": "integer"}, "description": {"description": "A detailed, evocative description of the property.", "title": "Description", "type": "string"}, "neighborhood_description": {"description": "A detailed, evocative description of the neighborhood in which the property is located.", "title": "Neighborhood Description", "type": "string"}}, "required": ["neighborhood", "price", "bedrooms", "bathrooms", "house_size", "description", "neighborhood_description"], "title": "RealEstate", "type": "object"}}, "properties": {"listings": {"description": "A list containing Real Estate details.", "items": {"$ref": "#/$defs/RealEstate"}, "title": "Listings", "type": "array"}}, "required": ["listings"]}
# ```

# %%
# Get the LLM response
llm_response = llm.invoke(query)

# %%
# Print the LLM Response
print(llm_response.content)
# Out:
# {
#   "listings": [
#     {
#       "neighborhood": "Green Oaks",
#       "price": 800000,
#       "bedrooms": 3,
#       "bathrooms": 2,
#       "house_size": 2000,
#       "description": "Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.",
#       "neighborhood_description": "Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze."
#     },
#     {
#       "neighborhood": "Sunnyvale",
#       "price": 950000,
#       "bedrooms": 4,
#       "bathrooms": 3,
#       "house_size": 2500,
#       "description": "Located in the desirable neighborhood of Sunnyvale, this 4-bedroom, 3-bathroom home offers spacious living areas and a beautifully landscaped backyard. The updated kitchen features stainless steel appliances and granite countertops, perfect for entertaining guests. Relax in the luxurious master suite with a spa-like bathroom and walk-in closet. Enjoy the California sunshine in the private backyard oasis with a pool and patio area.",
#       "neighborhood_description": "Sunnyvale is known for its top-rated schools, family-friendly community events, and proximity to tech companies like Apple and Google. Explore the nearby parks, shopping centers, and restaurants, or take a short drive to the vibrant city of San Francisco."
#     },
#     {
#       "neighborhood": "Downtown Los Angeles",
#       "price": 1200000,
#       "bedrooms": 2,
#       "bathrooms": 2,
#       "house_size": 1800,
#       "description": "Experience luxury living in the heart of Downtown Los Angeles in this modern 2-bedroom, 2-bathroom condo. The open floor plan features floor-to-ceiling windows with stunning city views, a gourmet kitchen with high-end appliances, and a spacious living room with a fireplace. The master suite offers a walk-in closet and a luxurious en-suite bathroom. Enjoy the building's amenities, including a rooftop pool, fitness center, and 24-hour concierge.",
#       "neighborhood_description": "Downtown Los Angeles is a vibrant neighborhood with a mix of historic architecture, trendy restaurants, and cultural attractions. Walk to the nearby museums, theaters, and art galleries, or take a short drive to the beaches of Santa Monica and Venice."
#     },
#     {
#       "neighborhood": "Brooklyn Heights",
#       "price": 1500000,
#       "bedrooms": 5,
#       "bathrooms": 4,
#       "house_size": 3000,
#       "description": "Step into this elegant 5-bedroom, 4-bathroom townhouse in the prestigious neighborhood of Brooklyn Heights. The historic brownstone features original details, including crown moldings, hardwood floors, and a decorative fireplace. The renovated kitchen boasts high-end appliances and custom cabinetry, perfect for the home chef. Relax in the private backyard garden or entertain guests in the formal dining room. Live in luxury in this Brooklyn Heights gem.",
#       "neighborhood_description": "Brooklyn Heights is a charming neighborhood with tree-lined streets, historic brownstones, and stunning views of the Manhattan skyline. Explore the nearby Brooklyn Bridge Park, boutique shops, and gourmet restaurants, or take a short subway ride to Manhattan for work or play."
#     },
#     {
#       "neighborhood": "Pacific Palisades",
#       "price": 3500000,
#       "bedrooms": 6,
#       "bathrooms": 5,
#       "house_size": 5000,
#       "description": "Live the California dream in this luxurious 6-bedroom, 5-bathroom estate in Pacific Palisades. The grand foyer leads to a formal living room with high ceilings and a fireplace, perfect for entertaining guests. The gourmet kitchen features top-of-the-line appliances and a breakfast nook overlooking the lush backyard. Relax in the master suite with a spa-like bathroom and a private balcony with ocean views. Enjoy the outdoor living spaces, including a pool, spa, and outdoor kitchen.",
#       "neighborhood_description": "Pacific Palisades is a prestigious neighborhood with upscale homes, scenic views, and a relaxed coastal vibe. Explore the nearby hiking trails, beaches, and shopping centers, or take a short drive to the iconic attractions of Los Angeles, including Beverly Hills and Hollywood."
#     },
#     {
#       "neighborhood": "South Beach",
#       "price": 2000000,
#       "bedrooms": 3,
#       "bathrooms": 3,
#       "house_size": 2200,
#       "description": "Experience luxury living in the vibrant neighborhood of South Beach in this modern 3-bedroom, 3-bathroom condo. The open floor plan features floor-to-ceiling windows with stunning bay views, a gourmet kitchen with high-end appliances, and a spacious living room with a fireplace. The master suite offers a walk-in closet and a luxurious en-suite bathroom. Enjoy the building's amenities, including a rooftop pool, fitness center, and 24-hour concierge.",
#       "neighborhood_description": "South Beach is known for its trendy restaurants, boutique shops, and lively nightlife. Walk to the nearby beaches, parks, and art galleries, or take a short drive to the cultural attractions of San Francisco."
#     },
#     {
#       "neighborhood": "Georgetown",
#       "price": 1800000,
#       "bedrooms": 4,
#       "bathrooms": 4,
#       "house_size": 2800,
#       "description": "Step into this elegant 4-bedroom, 4-bathroom townhouse in the historic neighborhood of Georgetown. The renovated home features modern amenities while preserving its original charm, including hardwood floors, exposed brick walls, and a gourmet kitchen. The master suite offers a spa-like bathroom and a private balcony overlooking the landscaped courtyard. Entertain guests in the formal dining room or relax in the cozy living room with a fireplace.",
#       "neighborhood_description": "Georgetown is a picturesque neighborhood with cobblestone streets, historic architecture, and upscale shops. Explore the nearby waterfront park, boutique stores, and gourmet restaurants, or take a short drive to the cultural attractions of Washington, D.C."
#     },
#     {
#       "neighborhood": "Nob Hill",
#       "price": 2500000,
#       "bedrooms": 3,
#       "bathrooms": 3,
#       "house_size": 2400,
#       "description": "Live in luxury in the prestigious neighborhood of Nob Hill in this 3-bedroom, 3-bathroom condo. The open floor plan features high ceilings, hardwood floors, and panoramic city views from every room. The gourmet kitchen boasts top-of-the-line appliances and a breakfast bar, perfect for entertaining guests. Relax in the master suite with a spa-like bathroom and a walk-in closet. Enjoy the building's amenities, including a rooftop terrace, fitness center, and 24-hour concierge.",
#       "neighborhood_description": "Nob Hill is a historic neighborhood with grand mansions, luxury hotels, and upscale restaurants. Walk to the nearby parks, theaters, and art galleries, or take a short drive to the iconic attractions of San Francisco, including the Golden Gate Bridge and Alcatraz Island."
#     },
#     {
#       "neighborhood": "Back Bay",
#       "price": 2200000,
#       "bedrooms": 2,
#       "bathrooms": 2,
#       "house_size": 2000,
#       "description": "Experience urban living in the vibrant neighborhood of Back Bay in this modern 2-bedroom, 2-bathroom condo. The open floor plan features floor-to-ceiling windows with stunning city views, a gourmet kitchen with high-end appliances, and a spacious living room with a fireplace. The master suite offers a walk-in closet and a luxurious en-suite bathroom. Enjoy the building's amenities, including a rooftop pool, fitness center, and 24-hour concierge.",
#       "neighborhood_description": "Back Bay is known for its historic brownstones, upscale shops, and trendy restaurants. Walk to the nearby parks, shopping centers, and cultural attractions, or take a short drive to the iconic landmarks of Boston, including Fenway Park and the Freedom Trail."
#     },
#     {
#       "neighborhood": "Tribeca",
#       "price": 3000000,
#       "bedrooms": 4,
#       "bathrooms": 3,
#       "house_size": 2800,
#       "description": "Step into this luxurious 4-bedroom, 3-bathroom loft in the trendy neighborhood of Tribeca. The open floor plan features exposed brick walls, high ceilings, and oversized windows with city views. The gourmet kitchen boasts top-of-the-line appliances and a breakfast bar, perfect for entertaining guests. Relax in the master suite with a spa-like bathroom and a walk-in closet. Enjoy the building's amenities, including a rooftop terrace, fitness center, and 24-hour concierge.",
#       "neighborhood_description": "Tribeca is a hip neighborhood with a mix of historic lofts, trendy restaurants, and art galleries. Explore the nearby parks, boutique shops, and cultural attractions, or take a short walk to the Hudson River Park for outdoor activities and stunning views of the city skyline."
#     }
#   ]
# }

# %%
# Create the DataFrame
result = parser.parse(llm_response.content)
listings = result.listings
df = pd.DataFrame([listing.model_dump() for listing in listings])

# %%
# Verify the created DataFrame
df.head()
# Out:
#            neighborhood    price  bedrooms  bathrooms  house_size  \
# 0            Green Oaks   800000         3          2        2000
# 1             Sunnyvale   950000         4          3        2500
# 2  Downtown Los Angeles  1200000         2          2        1800
# 3      Brooklyn Heights  1500000         5          4        3000
# 4     Pacific Palisades  3500000         6          5        5000
#
#                                          description  \
# 0  Welcome to this eco-friendly oasis nestled in ...
# 1  Located in the desirable neighborhood of Sunny...
# 2  Experience luxury living in the heart of Downt...
# 3  Step into this elegant 5-bedroom, 4-bathroom t...
# 4  Live the California dream in this luxurious 6-...
#
#                             neighborhood_description
# 0  Green Oaks is a close-knit, environmentally-co...
# 1  Sunnyvale is known for its top-rated schools, ...
# 2  Downtown Los Angeles is a vibrant neighborhood...
# 3  Brooklyn Heights is a charming neighborhood wi...
# 4  Pacific Palisades is a prestigious neighborhoo...

# %%
# Save the DataFrame to a CSV
df.to_csv("Real_Estates.csv", index_label="id")

# %% [markdown]
# # CREATING THE VECTOR DATABASE

# %%
# Defining paths and embedding functions

LANCEDB_PATH = "content/lancedb-1"
CSV_PATH = "Real_Estates.csv"
TABLE_NAME = "real_estates"

embedding_function = OpenAIEmbeddings()

# %%
# Reading the CSV data
try:
    df = pd.read_csv(CSV_PATH)
except FileNotFoundError as e:
    print(f"Caught a FileNotFoundError: {e}")

# %%
# Creating documents from the CSV
try:
    documents = []
    for index, row in df.iterrows():
        documents.append(Document(page_content=row["description"], metadata={"id": str(index)}))
    print(f"Successfully Created {len(documents)} documents.")
except Exception as ex:
    print(f"Caught an unexpected error:\n{ex}")
# Out:
# Successfully Created 10 documents.

# %%
# Initialize the text splitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=300,
    chunk_overlap=100,
    length_function=len,
    add_start_index=True
)

# %%
# Create the chunks
chunks = text_splitter.split_documents(documents)
print(f"{len(chunks)} chunks successfully created from {len(documents)} documents.")
# Out:
# 21 chunks successfully created from 10 documents.

# %%
# Verify a chunk
if chunks:
    random_index = random.randrange(0, len(chunks))
    document = chunks[random_index]
    print(f"Page Content: {document.page_content}")
    print(f"Metadata: {document.metadata}")
# Out:
# Page Content: appliances and granite countertops, perfect for entertaining guests. Relax in the luxurious master suite with a spa-like bathroom and walk-in closet. Enjoy the California sunshine in the private backyard oasis with a pool and patio area.
# Metadata: {'id': '1', 'start_index': 197}

# %%
# Populate the Vector Database (LanceDB)
try:
    if os.path.exists(LANCEDB_PATH):
        shutil.rmtree(LANCEDB_PATH)
    print("Populating LanceDB...")
    db = LanceDB.from_documents(
        documents=chunks,
        embedding=embedding_function,
        uri=LANCEDB_PATH,
        table_name=TABLE_NAME
    )
    print(f"Successfully populated LanceDB at {LANCEDB_PATH} with {len(chunks)} chunks in table {TABLE_NAME}")
except Exception as ex:
    print(f"Caught an unexpected exception:\n{ex}")
# Out:
# Populating LanceDB...
# Successfully populated LanceDB at content/lancedb-1 with 21 chunks in table real_estates

# %% [markdown]
# # FETCHING DATA FROM THE VECTOR DATABASE

# %%
query_text = "A comfortable three-bedroom house with a spacious kitchen and a cozy living room."
    
BASIC_PROMPT_TEMPLATE = \
"""
Based on the following context:
    
{context}
    
    
-----
    
Answer the question : {question}
"""

# %%
# Creating the function to predict responses.

def predict_response(query, template):
    try:
        db_connection = lancedb.connect(LANCEDB_PATH)
    except Exception as ex:
        print(f"Error establishing connection to LanceDB at {LANCEDB_PATH}. Did you run the ingestion script correctly?")
        print(f"Details:\n{ex}")
        return
    db = LanceDB(
        connection=db_connection,
        table_name=TABLE_NAME,
        embedding=embedding_function
    )

    results = db.similarity_search_with_relevance_scores(query, k=3)

    if len(results) == 0 or results[0][1] < 0.7:
        print("Unable to find relevant matches for your query")
        return

    context_text = "\n\n----\n\n".join([doc.page_content for doc, _ in results])
    prompt_template = ChatPromptTemplate.from_template(template)
    prompt = prompt_template.format(context=context_text, question=query)
    print(f"Generated Prompt:\n{prompt}")

    llm_response = llm.invoke(prompt).content
    sources = [doc.metadata.get("id", None) for doc, _ in results]
    return f"Response: {llm_response}\nSources: {sources}"

# %%
response = predict_response(query=query_text, template=BASIC_PROMPT_TEMPLATE)
print(response)
# Out:
# Generated Prompt:
# Human:
# Based on the following context:
#
# and a decorative fireplace. The renovated kitchen boasts high-end appliances and custom cabinetry, perfect for the home chef. Relax in the private backyard garden or entertain guests in the formal dining room. Live in luxury in this Brooklyn Heights gem.
#
# ----
#
# Step into this luxurious 4-bedroom, 3-bathroom loft in the trendy neighborhood of Tribeca. The open floor plan features exposed brick walls, high ceilings, and oversized windows with city views. The gourmet kitchen boasts top-of-the-line appliances and a breakfast bar, perfect for entertaining
#
# ----
#
# floors, exposed brick walls, and a gourmet kitchen. The master suite offers a spa-like bathroom and a private balcony overlooking the landscaped courtyard. Entertain guests in the formal dining room or relax in the cozy living room with a fireplace.
#
#
# -----
#
# Answer the question : A comfortable three-bedroom house with a spacious kitchen and a cozy living room.
#
# Response: Based on the context provided, it seems like the comfortable three-bedroom house with a spacious kitchen and a cozy living room would be a great option for someone looking for a cozy and inviting home. The high-end appliances and custom cabinetry in the kitchen, as well as the decorative fireplace in the living room, would add to the comfort and luxury of the space. Additionally, the private backyard garden would provide a peaceful outdoor retreat.
# Sources: ['3', '9', '6']

# %%
AUGMENT_PROMPT_TEMPLATE =\
"""
Based on the following context:

{context}

---

craft a response that not only answers the question {question}, but also ensures that your explanation is distinct, captivating, and customized to align with the specified preferences. This involves subtly emphasizing aspects of the property that align with what the buyer is looking for.
"""

# %%
augmented_response = predict_response(query=query_text, template=AUGMENT_PROMPT_TEMPLATE)
print(augmented_response)
# Out:
# Generated Prompt:
# Human:
# Based on the following context:
#
# and a decorative fireplace. The renovated kitchen boasts high-end appliances and custom cabinetry, perfect for the home chef. Relax in the private backyard garden or entertain guests in the formal dining room. Live in luxury in this Brooklyn Heights gem.
#
# ----
#
# Step into this luxurious 4-bedroom, 3-bathroom loft in the trendy neighborhood of Tribeca. The open floor plan features exposed brick walls, high ceilings, and oversized windows with city views. The gourmet kitchen boasts top-of-the-line appliances and a breakfast bar, perfect for entertaining
#
# ----
#
# floors, exposed brick walls, and a gourmet kitchen. The master suite offers a spa-like bathroom and a private balcony overlooking the landscaped courtyard. Entertain guests in the formal dining room or relax in the cozy living room with a fireplace.
#
# ---
#
# craft a response that not only answers the question A comfortable three-bedroom house with a spacious kitchen and a cozy living room., but also ensures that your explanation is distinct, captivating, and customized to align with the specified preferences. This involves subtly emphasizing aspects of the property that align with what the buyer is looking for.
#
# Response: Step into this charming three-bedroom house that exudes comfort and warmth. The spacious kitchen is a chef's dream, equipped with high-end appliances and custom cabinetry perfect for creating culinary masterpieces. The cozy living room is the ideal spot to unwind by the fireplace after a long day. With its inviting atmosphere and thoughtful design, this home is sure to be a sanctuary for relaxation and enjoyment.
# Sources: ['3', '9', '6']
